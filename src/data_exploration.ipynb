# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../football_wages.csv')
df.head()
# Out:
#     age  height_cm  weight_kg   nationality_name  overall  potential  \
# 0  27.0      183.0       76.0  b'Korea Republic'     57.0       58.0
# 1  21.0      182.0       70.0          b'France'     61.0       72.0
# 2  35.0      182.0       75.0  b'Korea Republic'     68.0       68.0
# 3  29.0      169.0       70.0        b'Paraguay'     67.0       67.0
# 4  30.0      176.0       74.0         b'Austria'     65.0       65.0
#
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                54.0                 30.0                        55.0
# 1                58.0                 63.0                        46.0
# 2                62.0                 68.0                        68.0
# 3                62.0                 55.0                        50.0
# 4                63.0                 49.0                        53.0
#
#    attacking_short_passing  ...  movement_reactions  movement_balance  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         5000 non-null   float64
#  1   height_cm                   5000 non-null   float64
#  2   weight_kg                   5000 non-null   float64
#  3   nationality_name            5000 non-null   object
#  4   overall                     5000 non-null   float64
#  5   potential                   5000 non-null   float64
#  6   attacking_crossing          5000 non-null   float64
#  7   attacking_finishing         5000 non-null   float64
#  8   attacking_heading_accuracy  5000 non-null   float64
#  9   attacking_short_passing     5000 non-null   float64
#  10  attacking_volleys           5000 non-null   float64
#  11  skill_dribbling             5000 non-null   float64
#  12  skill_curve                 5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#                age   height_cm    weight_kg      overall    potential  \
# count  5000.000000  5000.00000  5000.000000  5000.000000  5000.000000
# mean     25.226000   181.48020    75.074400    65.831000    71.127000
# std       4.774336     6.76603     6.994101     6.924076     6.091001
# min      16.000000   158.00000    51.000000    47.000000    51.000000
# 25%      21.000000   177.00000    70.000000    61.000000    67.000000
# 50%      25.000000   182.00000    75.000000    66.000000    71.000000
# 75%      29.000000   186.00000    80.000000    70.000000    75.000000
# max      42.000000   201.00000   103.000000    91.000000    93.000000
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# count         5000.000000          5000.000000                 5000.000000
# mean            49.336800            45.768600                   51.686000
# std             18.236784            19.956039                   17.547461
# ...

# %%
df["nationality_name"].nunique()
# Out:
# 131

# %%
df["nationality_name"].unique()
# Out:
# array(["b'Korea Republic'", "b'France'", "b'Paraguay'", "b'Austria'",
#        "b'Colombia'", "b'Spain'", "b'Norway'", "b'Croatia'",
#        "b'Saudi Arabia'", "b'Scotland'", "b'Nigeria'", "b'Argentina'",
#        "b'England'", "b'Republic of Ireland'", "b'Japan'", "b'Canada'",
#        "b'Germany'", "b'Italy'", "b'Wales'", "b'Hungary'", "b'Bolivia'",
#        "b'Mexico'", "b'Tunisia'", "b'China PR'", "b'Switzerland'",
#        "b'Belgium'", "b'North Macedonia'", "b'Uganda'", "b'Ecuador'",
#        "b'Uruguay'", "b'Guinea'", "b'Brazil'", "b'Portugal'", "b'Mali'",
#        "b'Turkey'", "b'Netherlands'", "b'Sweden'", "b'Australia'",
#        "b'Serbia'", "b'Congo DR'", "b'Northern Ireland'", "b'Ghana'",
#        "b'Curacao'", "b'Greece'", "b'Ivory Coast'", "b'Romania'",
#        "b'Cameroon'", "b'Albania'", "b'South Africa'", "b'Denmark'",
#        "b'Jamaica'", "b'Venezuela'", "b'United States'", "b'Costa Rica'",
#        "b'Senegal'", "b'Chile'", "b'Belize'", "b'Morocco'",
# ...

# %%
df["nationality_name"].value_counts()
# Out:
# nationality_name
# b'England'        489
# b'Germany'        368
# b'Spain'          273
# b'Argentina'      258
# b'France'         242
#                  ...
# b'Eritrea'          1
# b'El Salvador'      1
# b'Libya'            1
# b'Zambia'           1
# b'Mozambique'       1
# Name: count, Length: 131, dtype: int64

# %%
nat_counts = df["nationality_name"].value_counts()

plt.figure(figsize=(20,6))
nat_counts.plot(kind="bar")
plt.title("nationalities distribution")
plt.show()

# %%
from preprocessing import run_pipeline_2

X_processed, y, preprocessor = run_pipeline_2(df)

feature_names = preprocessor.get_feature_names_out()
X_df = pd.DataFrame(X_processed, columns=feature_names)

X_df.head()

X_df.info()

X_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   num__age                         5000 non-null   float64
#  1   num__height_cm                   5000 non-null   float64
#  2   num__weight_kg                   5000 non-null   float64
#  3   num__overall                     5000 non-null   float64
#  4   num__potential                   5000 non-null   float64
#  5   num__attacking_crossing          5000 non-null   float64
#  6   num__attacking_finishing         5000 non-null   float64
#  7   num__attacking_heading_accuracy  5000 non-null   float64
#  8   num__attacking_short_passing     5000 non-null   float64
#  9   num__attacking_volleys           5000 non-null   float64
#  10  num__skill_dribbling             5000 non-null   float64
# ...
